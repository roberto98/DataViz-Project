# %%
import numpy as np
import matplotlib.pyplot as plt

arr = np.array([10,20,30,10,15,20,10,5,1,1,1,30,20,2,10,20,30])
np.sum(arr)
plt.plot(arr)

# %%
plt.plot(10*arr)

# %%
desired_sum = 10000
cur_sum = np.sum(arr)
ratio = desired_sum / cur_sum
arr_new = ratio * arr
print(np.sum(arr_new))
plt.plot(arr_new)
# Out:
# 10000.0

# %%
tuple_ = (1,2,3)
tuple_[0] = 5
tuple_
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [9], line 2
#       1 tuple_ = (1,2,3)
# ----> 2 tuple_[0] = 5
#       3 tuple_
#
# TypeError: 'tuple' object does not support item assignment
